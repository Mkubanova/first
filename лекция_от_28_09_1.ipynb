# %% [markdown]
# <a href="https://colab.research.google.com/github/Mkubanova/first/blob/main/%D0%BB%D0%B5%D0%BA%D1%86%D0%B8%D1%8F_%D0%BE%D1%82_28_09_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1+1

# %%
3+5
# Out:
# 8

# %%
import pandas as pd
df = pd.DataFrame({'x':[1,2,3],'y':[2,4,1]})

# %%
df
# Out:
#    x  y
# 0  1  2
# 2  3  1

# %%
df.drop(1, axis=0, inplace=True)

# %%
df.reset_index(drop=False)
# Out:
#    index  x  y
# 0      0  1  2
# 1      2  3  1

# %%
df1 = pd.DataFrame({'x':[1,3,2], 'y':[2,4,1]})
df2 = pd.DataFrame({'x':[3,1,2], 'y':[0,2,2]})

# %%
df1
# Out:
#    x  y
# 0  1  2
# 1  3  4
# 2  2  1

# %%
df2
# Out:
#    x  y
# 0  3  0
# 1  1  2
# 2  2  2

# %%
df2.isna()
# Out:
#        x      y
# 0  False  False
# 1  False  False
# 2  False  False

# %%
df2.isnull()
# Out:
#        x      y
# 0  False  False
# 1  False  False
# 2  False  False

# %%
data = {'Цвет': ['Красный', 'Синий', 'Зеленый', 'Красный', 'Желтый',
'Зеленый']}
df = pd.DataFrame(data)

# %%
df
# Out:
#       Цвет
# 0  Красный
# 1    Синий
# 2  Зеленый
# 3  Красный
# 4   Желтый
# 5  Зеленый

# %%
unique_colors = df['Цвет'].unique()

# %%
unique_colors
# Out:
# array(['Красный', 'Синий', 'Зеленый', 'Желтый'], dtype=object)
